# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import statistics
df2 =pd.read_csv('C:/newfile.csv')
df =pd.read_csv('C:/state_pop2.csv')
c = list(df['Year'])
dfz = pd.DataFrame((df2.iloc[0:51]/df.iloc[0:51])*100)
dfz
# Out:
#          AK        AL        AR        AZ        CA        CO        CT  \
# 0  0.023078  0.133131  0.102154  0.048997  0.057194  0.083558  0.040768
# 1  0.028656  0.172778  0.125724  0.086428  0.098879  0.109147  0.055478
# 2  0.036629  0.175790  0.138185  0.141696  0.147855  0.139556  0.072267
# 3  0.034312  0.164706  0.127242  0.150913  0.161194  0.142474  0.071175
# 4  0.130204  0.619865  0.482396  0.544365  0.617336  0.571413  0.256024
# 5  0.019150  0.136920  0.099265  0.084982  0.103586  0.111872  0.047443
# 6  0.013028  0.128792  0.087878  0.074857  0.070319  0.085580  0.043326
# 7  0.013031  0.123864  0.085206  0.059360  0.054970  0.069649  0.042290
# 8  0.014911  0.127074  0.087177  0.054389  0.046071  0.056489  0.036795
# 9  0.013344  0.130652  0.084297  0.048636  0.042278  0.051439  0.036293
#
#          DE        FL        GA  ...       TOTAL        TX        UT  \
# 0  0.050703  0.063334  0.142546  ...    0.072512  0.044382  0.062708
# 1  0.071051  0.095718  0.175479  ...    0.094844  0.044588  0.097483
# 2  0.095320  0.127387  0.189380  ...    0.116433  0.053081  0.135638
# 3  0.094464  0.135184  0.195284  ...    0.115420  0.053232  0.155369
# 4  0.393645  0.475463  0.729850  ...    0.437282  0.188884  0.632714
# 5  0.068485  0.093491  0.152814  ...    0.084283  0.041612  0.122733
# 6  0.062892  0.085676  0.131188  ...    0.072922  0.032187  0.109658
# 7  0.055725  0.073544  0.124732  ...    0.064154  0.030191  0.105002
# 8  0.052856  0.058400  0.116977  ...    0.058889  0.028750  0.090683
# 9  0.058925  0.047539  0.113168  ...    0.055196  0.028493  0.088588
#
#          VA        VT        WA        WI        WV        WY   Year
# 0  0.069243  0.035446  0.061595  0.070703  0.058995  0.030474  100.0
# 1  0.095487  0.054314  0.088887  0.089612  0.071673  0.041206  100.0
# 2  0.108631  0.058897  0.116897  0.111390  0.087998  0.058944  100.0
# 3  0.103429  0.053835  0.115108  0.114090  0.067198  0.059520  100.0
# 4  0.403204  0.174557  0.452501  0.464338  0.247713  0.232859  100.0
# 5  0.077099  0.036236  0.089105  0.091021  0.047453  0.042998  100.0
# 6  0.072724  0.033007  0.076995  0.083321  0.041981  0.045994  100.0
# 7  0.066331  0.025200  0.064912  0.072955  0.041276  0.033925  100.0
# 8  0.065061  0.025875  0.055682  0.067044  0.037696  0.025914  100.0
# 9  0.061069  0.019853  0.048244  0.064392  0.039757  0.035525  100.0
#
# [10 rows x 52 columns]

# %%
df9 =pd.read_csv('C:/health.csv')
df9
# Out:
#    Year    opexpenses  expensesgrowth
# 0  2007  2.900000e+11            5.77
# 1  2008  2.950000e+11            1.68
# 2  2009  2.930000e+11           -0.60
# 3  2010  2.990000e+11            1.87
# 4  2011  3.090000e+11            3.17
# 5  2012  3.180000e+11            2.86
# 6  2013  3.250000e+11            2.31
# 7  2014  3.300000e+11            1.37
# 8  2015  3.380000e+11            2.51
# 9  2016  3.500000e+11            3.50

# %%
df6 =pd.read_csv('C:/unemployment1.csv')
df8 =pd.read_csv('C:/mortgages.csv')
df9 =pd.read_csv('C:/health.csv')
filing = list(dfz['TOTAL'])
unemploy = list(df6['TOTAL'])
mortgage = list(df8['TOTAL'])
health = list(df9['expensesgrowth'])
combined = pd.DataFrame()
combined['Year'] = c
combined['Filing_Rate'] = filing
combined['Unemployment_Rate'] = unemploy
-Rcombined['Mortgage_Delinquency'] = mortgage
combined['Health_Exp_Growth'] = health
combined
# Out:
#    Year  Filing_Rate  Unemployment_Rate  Mortgage_Delinquency  \
# 0  2007     0.072512                4.6                   1.5
# 1  2008     0.094844                5.8                   2.7
# 2  2009     0.116433                9.3                   4.8
# 3  2010     0.115420                9.6                   4.1
# 4  2011     0.437282                8.9                   4.0
# 5  2012     0.084283                8.1                   3.3
# 6  2013     0.072922                7.4                   2.6
# 7  2014     0.064154                6.2                   2.2
# 8  2015     0.058889                5.3                   1.6
# 9  2016     0.055196                4.9                   1.3
#
#    Health_Exp_Growth
# 0               5.77
# 1               1.68
# 2              -0.60
# 3               1.87
# 4               3.17
# 5               2.86
# 6               2.31
# 7               1.37
# 8               2.51
# 9               3.50

# %%
combined = combined.drop(combined.index[4])
combined
# Out:
#       Filing_Rate  Unemployment_Rate  Mortgage_Delinquency  Health_Exp_Growth
# Year
# 2007     0.072512                4.6                   1.5               5.77
# 2008     0.094844                5.8                   2.7               1.68
# 2009     0.116433                9.3                   4.8              -0.60
# 2010     0.115420                9.6                   4.1               1.87
# 2013     0.072922                7.4                   2.6               2.31
# 2014     0.064154                6.2                   2.2               1.37
# 2015     0.058889                5.3                   1.6               2.51
# 2016     0.055196                4.9                   1.3               3.50

# %%
plt.scatter(x=combined['Unemployment_Rate'], y=combined['Filing_Rate'])
plt.xlabel('Unemployment Rate')
plt.ylabel('Bankruptcy Filings Rate')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
fig, ax = plt.subplots()
fit = np.polyfit(combined['Unemployment_Rate'], combined['Filing_Rate'], deg=1,)
ax.plot(combined['Unemployment_Rate'], fit[0] * combined['Unemployment_Rate'] + fit[1], color='orange')
ax.scatter(combined['Unemployment_Rate'], combined['Filing_Rate'], color ='crimson')
fig.show()
# Out:
# c:\users\mrinalini's pc\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
plt.scatter(x=combined['Mortgage_Delinquency'], y=combined['Filing_Rate'])
plt.xlabel(' 90-Day Mortgage Delinquency Rate')
plt.ylabel('Bankruptcy Filings Rate')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
fig, ax = plt.subplots()
fit = np.polyfit(combined['Mortgage_Delinquency'], combined['Filing_Rate'], deg=1)
ax.plot(combined['Mortgage_Delinquency'], fit[0] * combined['Mortgage_Delinquency'] + fit[1], color='orange')
ax.scatter(combined['Mortgage_Delinquency'], combined['Filing_Rate'])
fig.show()
# Out:
# c:\users\mrinalini's pc\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
plt.scatter(x=combined['Health_Exp_Growth'], y=combined['Filing_Rate'])
plt.xlabel('Growth of Health Expenses')
plt.ylabel('Bankruptcy Filings Rate')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
fig, ax = plt.subplots()
fit = np.polyfit(combined['Health_Exp_Growth'], combined['Filing_Rate'], deg=1)
ax.plot(combined['Health_Exp_Growth'], fit[0] * combined['Health_Exp_Growth'] + fit[1], color='orange')
ax.scatter(combined['Health_Exp_Growth'], combined['Filing_Rate'])
fig.show()
# Out:
# c:\users\mrinalini's pc\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
combined.corr(method = 'pearson')
# Out:
#                       Filing_Rate  Unemployment_Rate  Mortgage_Delinquency  \
# Filing_Rate              1.000000           0.834656              0.935471
# Unemployment_Rate        0.834656           1.000000              0.947368
# Mortgage_Delinquency     0.935471           0.947368              1.000000
# Health_Exp_Growth       -0.560094          -0.705802             -0.761765
#
#                       Health_Exp_Growth
# Filing_Rate                   -0.560094
# Unemployment_Rate             -0.705802
# Mortgage_Delinquency          -0.761765
# Health_Exp_Growth              1.000000
